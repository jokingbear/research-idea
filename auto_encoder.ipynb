# %%
import torch
import torch.nn as nn
import torch.optim as opts
import h5py as h5
import model
import cv2

from plasma.modules import *
from plasma.training import StandardDataset, Trainer, callbacks
from albumentations import ShiftScaleRotate

# %% [markdown]
# # repo

# %%
aug = ShiftScaleRotate(shift_limit=0.1, scale_limit=0.15, rotate_limit=25, border_mode=cv2.BORDER_CONSTANT, p=0.3)

# %%
class Repo(StandardDataset):
    
    def __init__(self, file, train=True):
        super().__init__()
        
        self.h5_file = h5.File(file, mode="r")
        self.train = train
    
    def get_len(self):
        return len(self.h5_file["image"])
    
    def get_item(self, idx):
        img = self.h5_file["image"][idx][None]
        
        if self.train:
            img = aug(image=img)["image"]
        
        return img, img

# %% [markdown]
# # train

# %%
encoder = model.DenseCap()

encoder.cuda(0)
# Out:
# DenseCap(
#   (con1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (con2): Sequential(
#     (0): ResBlock(
#       (skip): Upsample(scale_factor=0.5, mode=bilinear)
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (1): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(160, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#   )
#   (con3): Sequential(
#     (0): BN_ReLU_Conv(
#       (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): ResBlock(
#       (skip): Upsample(scale_factor=0.5, mode=bilinear)
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(160, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (4): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(224, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (5): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (6): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(288, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#   )
#   (con4): Sequential(
#     (0): BN_ReLU_Conv(
#       (norm): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): ResBlock(
#       (skip): Upsample(scale_factor=0.5, mode=bilinear)
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(288, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (4): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(352, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (5): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (6): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(416, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (7): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(448, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (8): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(480, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (9): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (10): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(544, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#   )
#   (con5): Sequential(
#     (0): BN_ReLU_Conv(
#       (norm): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(576, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): ResBlock(
#       (skip): Upsample(scale_factor=0.5, mode=bilinear)
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(544, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(576, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (4): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(608, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (5): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(640, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (6): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(672, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (7): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(704, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (8): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(736, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (9): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (10): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(800, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (11): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (12): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(864, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#   )
#   (con6): Sequential(
#     (0): BN_ReLU_Conv(
#       (norm): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(896, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): ResBlock(
#       (skip): Upsample(scale_factor=0.5, mode=bilinear)
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(1056, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(1088, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (4): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(1120, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (5): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(1152, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (6): ResBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(1184, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): ChannelAttention(
#           in_channels=8, ratio=0.5, axes=[2, 3], groups=32
#           (attention): Sequential(
#             (0): GlobalAverage(axes=[2, 3], keepdims=True)
#             (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#             (4): Sigmoid()
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=8, out_channels=32, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (7): BN_ReLU_Conv(
#       (norm): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(1216, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
# )

# %%
decoder = model.Decoder()

decoder.cuda(0)
# Out:
# Decoder(
#   (con1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (con2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (con3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (con4): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (con5): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (3): Upsample(scale_factor=2.0, mode=bilinear)
#     (4): BN_ReLU_Conv(
#       (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): Tanh()
#   )
# )

# %%
ae = nn.Sequential(encoder, decoder)

# %%
loss = nn.MSELoss()

# %%
opt = opts.SGD(ae.parameters(), lr=0.25, momentum=0.9, nesterov=True)

# %%
trainer = Trainer(ae, opt, loss, x_device="cuda:0", y_type=torch.float, y_device="cuda:0")

# %%
cbs = [
    callbacks.WarmRestart(1e-5, model_name="ae_256x256"),
    callbacks.CSVLogger("train.csv")
]

# %%
trainer.fit(Repo("data.h5"), test=Repo("test.h5", train=False), callbacks=cbs, batch_size=8, val_batch_size=8)
# Out:
# epoch 1
# HBox(children=(FloatProgress(value=0.0, description='train', max=1505.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='evaluate', max=401.0, style=ProgressStyle(description_wid…
# epoch 2
# HBox(children=(FloatProgress(value=0.0, description='train', max=1505.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='evaluate', max=401.0, style=ProgressStyle(description_wid…
# epoch 3
# HBox(children=(FloatProgress(value=0.0, description='train', max=1505.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='evaluate', max=401.0, style=ProgressStyle(description_wid…
# epoch 4
# HBox(children=(FloatProgress(value=0.0, description='train', max=1505.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='evaluate', max=401.0, style=ProgressStyle(description_wid…
# epoch 5
# HBox(children=(FloatProgress(value=0.0, description='train', max=1505.0, style=ProgressStyle(description_width…
