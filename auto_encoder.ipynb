# %%
import torch
import torch.nn as nn
import torch.optim as opts
import h5py as h5
import model
# import model2 as model
import cv2

from plasma.modules import *
from plasma.training import StandardDataset, Trainer, callbacks
from albumentations import ShiftScaleRotate, Compose, HorizontalFlip

# %% [markdown]
# # repo

# %%
aug = Compose([
    HorizontalFlip(p=0.5),
    ShiftScaleRotate(shift_limit=0.1, rotate_limit=25, border_mode=cv2.BORDER_CONSTANT, p=0.3)
], p=1)

# %%
class Repo(StandardDataset):
    
    def __init__(self, file, train=True):
        super().__init__()
        
        self.h5_file = h5.File(file, mode="r")
        self.train = train
    
    def get_len(self):
        return len(self.h5_file["image"])
    
    def get_item(self, idx):
        img = self.h5_file["image"][idx][None]
        
        if self.train:
            img = aug(image=img)["image"]
        
        return img, img

# %% [markdown]
# # callback

# %%
from torchvision.utils import save_image

class RenderImage(callbacks.Callback):
    
    def on_validation_batch_end(self, batch, x, y, pred):
        if batch % 50 == 0:
            img = torch.stack([y, pred], dim=1).flatten(start_dim=0, end_dim=1)
        
            save_image(img, f"check/{batch}.png", normalize=True, nrow=2)

# %% [markdown]
# # train

# %%
encoder = model.DenseCap()

encoder.cuda(0)
# Out:
# DenseCap(
#   (con1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (con2): Sequential(
#     (0): Upsample(scale_factor=0.5, mode=bilinear)
#     (1): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (2): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(192, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#   )
#   (con3): Sequential(
#     (0): BN_ReLU_Conv(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): Upsample(scale_factor=0.5, mode=bilinear)
#     (2): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(192, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (4): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#   )
#   (con4): Sequential(
#     (0): BN_ReLU_Conv(
#       (norm): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): Upsample(scale_factor=0.5, mode=bilinear)
#     (2): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(320, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (4): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (5): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(448, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (6): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (7): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(576, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (8): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(640, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#   )
#   (con5): Sequential(
#     (0): BN_ReLU_Conv(
#       (norm): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(704, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): Upsample(scale_factor=0.5, mode=bilinear)
#     (2): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(576, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (4): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(640, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (5): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(704, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (6): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (7): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(832, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (8): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(896, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#   )
#   (con6): Sequential(
#     (0): BN_ReLU_Conv(
#       (norm): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(960, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (1): Upsample(scale_factor=0.5, mode=bilinear)
#     (2): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (3): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(832, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (4): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(896, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (5): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(960, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (6): DenseBlock(
#       (skip): Identity()
#       (con): Sequential(
#         (0): BN_ReLU_Conv(
#           (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): Sequential(
#           (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): ChannelAttention(
#             in_channels=16, ratio=0.5, axes=[2, 3], groups=32
#             (attention): Sequential(
#               (0): GlobalAverage(axes=[2, 3], keepdims=True)
#               (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (2): ReLU(inplace=True)
#               (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), groups=32)
#               (4): Sigmoid()
#             )
#           )
#         )
#         (2): BN_ReLU_Conv(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         )
#         (3): BN_ReLU_Routing(
#           (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#           (con): DynamicRouting2d(in_channels=16, out_channels=64, groups=32, iters=1, bias=False)
#         )
#       )
#     )
#     (7): BN_ReLU_Conv(
#       (norm): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(1088, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
# )

# %%
decoder = model.Decoder()

decoder.cuda(0)
# Out:
# Decoder(
#   (con1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(1024, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (con2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(768, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (con3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (con4): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (con5): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): BN_ReLU_Conv(
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): BN_ReLU_Conv(
#       (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (3): Upsample(scale_factor=2.0, mode=bilinear)
#     (4): BN_ReLU_Conv(
#       (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#       (con): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): Tanh()
#   )
# )

# %%
ae = nn.Sequential(encoder, decoder)

# %%
loss = nn.MSELoss()

# %%
opt = opts.SGD(ae.parameters(), lr=0.2, momentum=0.9, nesterov=True)

# %%
trainer = Trainer(ae, opt, loss, x_device="cuda:0", y_type=torch.float, y_device="cuda:0")

# %%
cbs = [
    callbacks.WarmRestart(1e-5, model_name="ae_256x256"),
    callbacks.CSVLogger("train.csv", append=True),
    RenderImage()
]

# %%
trainer.fit(Repo("data.h5"), test=Repo("test.h5", train=False), callbacks=cbs, batch_size=8, val_batch_size=8)
# Out:
# epoch 1
# HBox(children=(FloatProgress(value=0.0, description='train', max=1505.0, style=ProgressStyle(description_width…
